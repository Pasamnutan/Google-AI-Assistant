# %% [markdown]
# <a href="https://colab.research.google.com/github/Pasamnutan/Google-AI-Assistant/blob/main/Google_AI_Assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ask_question(name):
  ques = 'Hey ' + name + ' what do you want ? '
  ques = input(ques)
  return ques

# %%
ask_question("nutan")
# Out:
# Hey nutan what do you want ? hi
# 'hi'

# %%
def classify_questions(ques):
    device_lst = ['Set an alarm', 'set a reminder', 'send a message', 'call']
    personal_lst = {'who are you?': 'I am Jarvis', 'who created you?': 'I am created by your username'}

    device = False
    for i in device_lst:
        if i in ques:
            device = True
            break

    if device:
        print("This question is related to Device things, which is not supported in our Google Assistant")

    personal_question = False
    for i in personal_lst:
        if i in ques:
            personal_question = True
            break

    if personal_question:
        print(f"Hey, I am a personal assistant created by your name")

    goahead_with_web_search = not (device or personal_question)
    return goahead_with_web_search

# Example usage:
ques = "Set an alarm"
result = classify_questions(ques)
print("Go ahead with web search:", result)
# Out:
# This question is related to Device things, which is not supported in our Google Assistant
# Go ahead with web search: False

# %%
classify_questions("Who are you?")
# Out:
# True

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.2/164.2 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 19.7 MB/s eta 0:00:00

# %%
import pathlib
import textwrap
import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown
from IPython.display import Audio, display


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
# %%time
response = model.generate_content("What is judicial system?")
# Out:
# CPU times: user 101 ms, sys: 9.45 ms, total: 111 ms
# Wall time: 7.54 s

# %%
response.text
# Out:
# "The judicial system is the **system of courts that interprets and applies the law**. It's a fundamental component of any functioning society, tasked with:\n\n**1. Resolving Disputes:** The judicial system provides a forum for resolving disputes between individuals, organizations, or the government. This can include civil disputes like contract breaches or personal injury, and criminal matters like theft or assault.\n\n**2. Ensuring Fairness and Justice:** The system aims to ensure that everyone is treated fairly and equally under the law, regardless of their social standing or wealth. It provides a mechanism for holding individuals and entities accountable for their actions.\n\n**3. Interpreting and Applying the Law:**  Judges interpret the meaning and application of laws passed by legislatures. They determine whether laws are constitutional and how they should be applied in specific cases. This process helps to clarify and refine the law over time.\n\n**4. Protecting Rights and Liberties:** The judicial system safeguards fundamental rights and freedoms guaranteed by the constitution or other legal instruments. It acts as a check on the power of the government and other institutions to ensure that they don't overstep their boundaries.\n\n**Key Components of a Judicial System:**\n\n* **Courts:** These are the venues where legal disputes are heard and decided upon. There are different levels of courts, with lower courts handling simpler cases and higher courts dealing with more complex or serious matters.\n* **Judges:** These are impartial officials who preside over court proceedings, hear evidence, and make legal rulings based on the law and established precedents.\n* **Lawyers:** These are legal professionals who represent clients in court, presenting their arguments and evidence.\n* **Jury:** In some systems, a jury of citizens is responsible for determining the facts of a case and reaching a verdict.\n* **Legal Procedures:** These are the rules and processes that govern how legal disputes are handled in court, including the presentation of evidence, the conduct of trials, and the appeals process.\n\n**Different Types of Judicial Systems:**\n\n* **Common Law:** This system is based on precedents set by previous court decisions. \n* **Civil Law:** This system relies primarily on written codes of law.\n* **Religious Law:** This system is based on religious doctrines and teachings.\n* **Mixed Systems:** Some countries combine elements of different systems.\n\n**Understanding the judicial system is crucial for understanding how a society functions and how its laws are enforced.** It's also essential for individuals to understand their rights and how they can access the justice system if they need to. \n"

# %%
to_markdown(response.text)
# Out:
# > The judicial system is the **system of courts that interprets and applies the law**. It's a fundamental component of any functioning society, tasked with:
# >
# > **1. Resolving Disputes:** The judicial system provides a forum for resolving disputes between individuals, organizations, or the government. This can include civil disputes like contract breaches or personal injury, and criminal matters like theft or assault.
# >
# > **2. Ensuring Fairness and Justice:** The system aims to ensure that everyone is treated fairly and equally under the law, regardless of their social standing or wealth. It provides a mechanism for holding individuals and entities accountable for their actions.
# >
# > **3. Interpreting and Applying the Law:**  Judges interpret the meaning and application of laws passed by legislatures. They determine whether laws are constitutional and how they should be applied in specific cases. This process helps to clarify and refine the law over time.
# >
# > **4. Protecting Rights and Liberties:** The judicial system safeguards fundamental rights and freedoms guaranteed by the constitution or other legal instruments. It acts as a check on the power of the government and other institutions to ensure that they don't overstep their boundaries.
# >
# > **Key Components of a Judicial System:**
# >
# > * **Courts:** These are the venues where legal disputes are heard and decided upon. There are different levels of courts, with lower courts handling simpler cases and higher courts dealing with more complex or serious matters.
# > * **Judges:** These are impartial officials who preside over court proceedings, hear evidence, and make legal rulings based on the law and established precedents.
# > * **Lawyers:** These are legal professionals who represent clients in court, presenting their arguments and evidence.
# > * **Jury:** In some systems, a jury of citizens is responsible for determining the facts of a case and reaching a verdict.
# > * **Legal Procedures:** These are the rules and processes that govern how legal disputes are handled in court, including the presentation of evidence, the conduct of trials, and the appeals process.
# >
# > **Different Types of Judicial Systems:**
# >
# > * **Common Law:** This system is based on precedents set by previous court decisions.
# > * **Civil Law:** This system relies primarily on written codes of law.
# > * **Religious Law:** This system is based on religious doctrines and teachings.
# > * **Mixed Systems:** Some countries combine elements of different systems.
# >
# > **Understanding the judicial system is crucial for understanding how a society functions and how its laws are enforced.** It's also essential for individuals to understand their rights and how they can access the justice system if they need to.

# %%
def ask_gemini(ques):
  response = model.generate_content(ques)

  return response.text

# %% [markdown]
# # New Section

# %%
have_any_other_ques = 'y'
name = ''
while have_any_other_ques == 'y':
  if name == '':
    name = input("What is your name?")
  q = ask_question(name)
  go_ahead = classify_questions(q)
  answer = ''
  if go_ahead == True:
    answer = ask_gemini(q)
  print(answer)
  speak(answer)


  have_any_other_ques = input("Do you have any other questions??")
# Out:
# What is your name?nutan
# Hey nutan what do you want ? Explain about Data Analytics?
# ## Data Analytics: Unveiling Insights from Raw Data
#
# Data analytics is the process of examining raw data to extract meaningful insights and patterns. It's like a detective story, where we gather clues (data) and use our tools (analytical techniques) to solve a mystery (understand the data).
#
# Here's a breakdown:
#
# **What is data analytics used for?**
#
# * **Identifying trends:** Understanding how things change over time and predicting future behaviour.
# * **Making better decisions:** Using data-driven insights to guide decisions and optimize processes.
# * **Solving problems:** Identifying root causes of issues and developing solutions.
# * **Improving efficiency:** Automating tasks and optimizing resource allocation.
# * **Personalizing experiences:** Tailoring services and products to individual needs and preferences.
#
# **Key Components of Data Analytics:**
#
# * **Data Collection:** Gathering data from various sources, like databases, sensors, social media, etc.
# * **Data Cleaning & Preparation:** Transforming raw data into a usable format, removing errors and inconsistencies.
# * **Data Exploration & Visualization:** Exploring the data to identify patterns and relationships, often through charts, graphs, and dashboards.
# * **Statistical Analysis:** Applying statistical techniques to uncover deeper insights and test hypotheses.
# * **Predictive Modeling:** Building models to predict future events based on historical data.
#
# **Types of Data Analytics:**
#
# * **Descriptive Analytics:**  Summarizes past data to understand what happened. Think of sales reports or website traffic analysis.
# * **Diagnostic Analytics:** Explores why things happened by analyzing the root causes. For example, finding out why sales dropped in a specific region.
# * **Predictive Analytics:**  Uses historical data to predict future outcomes. This is used in forecasting, risk assessment, and customer churn prediction.
# * **Prescriptive Analytics:**  Recommends actions to take based on the predicted outcomes. This helps businesses optimize operations and make strategic decisions.
#
# **Tools and Technologies:**
#
# * **Software:**  Tableau, Power BI, Qlik Sense, R, Python, SAS
# * **Databases:**  SQL Server, Oracle, MySQL
# * **Cloud platforms:**  AWS, Azure, Google Cloud
#
# **Benefits of Data Analytics:**
#
# * **Improved decision-making:**  Data-driven decisions are more informed and lead to better outcomes.
# * **Increased efficiency:**  Automate tasks, optimize processes, and improve resource allocation.
# * **Enhanced customer experience:**  Personalize products and services based on customer data.
# * **Competitive advantage:**  Gain insights into market trends, customer behaviour, and competitor strategies.
#
# **In Conclusion:**
#
# Data analytics is a powerful tool that can help businesses, organizations, and individuals gain valuable insights from data. By harnessing the power of data, we can make better decisions, solve problems, and improve efficiency. It's a constantly evolving field, with new tools and techniques emerging all the time.
#
# Do you have any other questions??n
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # New Section

# %%
! pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2024.7.4)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.5.1

# %%
from gtts import gTTS

# %%
tts = gTTS('hello')

# %%
 tts.save('audio.mp3')

# %%
def speak(answer):
  tts = gTTS(answer)
  tts.save('audio.mp3')
  display(Audio('audio.mp3', autoplay=True))

# %%
speak("room is cosy")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
